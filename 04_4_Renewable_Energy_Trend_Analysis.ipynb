# %% [markdown]
# <a href="https://colab.research.google.com/github/luvnz/ISYS5002_2023_s2/blob/main/04_4_Renewable_Energy_Trend_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Renewable Energy Trends Analysis: Hydro, Wind, and Solar Energy
#
# The [dataset](https://www.abs.gov.au/statistics/industry/energy/energy-account-australia/2020-21#renewable-energy-use) presents a comprehensive overview of renewable energy sources, specifically hydro, wind, and solar energy, over a span of two decades. The provided data showcases the energy production levels in petajoules (PJ) for each source from the financial year 2002-03 to 2020-21.
#
# Source:
# This dataset is sourced from the Australian Bureau of Statistics' "Energy Account, Australia" report for the 2020-21 financial year, providing valuable insights into the nation's renewable energy sector.
#
# Source: https://www.abs.gov.au/statistics/industry/energy/energy-account-australia/2020-21

# %%
#import csv module
import csv

# %%
with open('data.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    next(csvreader)  # Skip header row
    for row in csvreader:
        print(row)
# Out:
# ['', 'Hydro energy (PJ)', 'Wind energy (PJ)', 'Solar energy (PJ)']
# ['2002-03', '60', '3', '3']
# ['2003-04', '59', '3', '3']
# ['2004-05', '57', '3', '3']
# ['2005-06', '58', '6', '3']
# ['2006-07', '53', '9', '6']
# ['2007-08', '44', '11', '7']
# ['2008-09', '43', '14', '9']
# ['2009-10', '49', '18', '12']
# ['2010-11', '61', '22', '17']
# ['2011-12', '51', '25', '22']
# ['2012-13', '66', '29', '27']
# ['2013-14', '66', '37', '29']
# ['2014-15', '48', '41', '35']
# ['2015-16', '55', '44', '40']
# ['2016-17', '59', '45', '45']
# ['2017-18', '58', '55', '53']
# ['2018-19', '57', '64', '72']
# ['2019-20', '55', '73', '94']
# ['2020-21', '55', '88', '120']
# []
# ['Source: Australian Bureau of Statistics, Energy Account, Australia 2020-21 financial year']

# %% [markdown]
# ### Read data from CSV file

# %%
# Initialize lists to store data
years = []
hydro_energy = []

with open('data.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    next(csvreader)  # Skip header row
    for row in csvreader:
        if len(row) < 2:
            print("Invalid data row:", row)
            continue
        years.append(row[0])
        hydro_energy.append(row[1])
# Out:
# Invalid data row: []
# Invalid data row: ['Source: Australian Bureau of Statistics, Energy Account, Australia 2020-21 financial year']

# %% [markdown]
# ### Plot graph
#
# https://matplotlib.org/stable/tutorials/introductory/pyplot.html

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(years, hydro_energy, marker='o', label='Hydro energy')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Energy (PJ)')
plt.title('Energy Generation Over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Read wind energy and solar energy data and plot graph
